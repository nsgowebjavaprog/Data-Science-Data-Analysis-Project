# %%
import matplotlib.pyplot as plt

x = [10,20,30,40]

y = [5,10,15,20]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [10,20,30,40]

y = [5,10,15,20]

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [10,20,30,40]

y = [5,10,15,20]

c = ["red","green","yellow","orange"]

plt.bar(x,y,color=c)
plt.show()

# %%
#   1.Line Plot

import matplotlib.pyplot as plt


x=[1,2,3,4]
y=[2,4,6,8]
plt.plot(x,y)
plt.show()

# %%
# 2.Bar Plot

import matplotlib.pyplot as plt

x = ["c","c++","JAVA","Python"]
y = [20,30,88,52]

plt.xlabel("Lanuages",fontsize=19)
plt.ylabel("Know")
plt.title("JUN-09-2024",fontsize=25)

plt.bar(x,y)
plt.show()

# %%
# 2.Bar Plot---width

import matplotlib.pyplot as plt

x = ["c","c++","JAVA","Python"]
y = [20,30,88,52]

plt.xlabel("Lanuages",fontsize=19)
plt.ylabel("Know")
plt.title("JUN-09-2024",fontsize=25)

plt.bar(x,y,width=0.3)   # width
plt.show()

# %%
# 2.Bar Plot---color

import matplotlib.pyplot as plt

x = ["c","c++","JAVA","Python"]
y = [20,30,88,52]

plt.xlabel("Lanuages",fontsize=19)
plt.ylabel("Know")
plt.title("JUN-09-2024",fontsize=25)

plt.bar(x,y,color="r")   # col
plt.show()

# %%
# 2.Bar Plot---multi--color

import matplotlib.pyplot as plt

x = ["c","c++","JAVA","Python"]
y = [20,30,88,52]

plt.xlabel("Lanuages",fontsize=19)
plt.ylabel("Know")
plt.title("JUN-09-2024",fontsize=25)

colorss=["y","r","orange","b"]

plt.bar(x,y,color=colorss)   # multi--col
plt.show()

# %%
# 2.Bar Plot---multi--color

import matplotlib.pyplot as plt

x = ["c","c++","JAVA","Python"]
y = [20,30,88,52]

plt.xlabel("Lanuages",fontsize=19)
plt.ylabel("Know")
plt.title("JUN-09-2024",fontsize=25)

colorss=["y","r","orange","b"]

plt.bar(x,y,color=colorss, align="center")   # by default center
plt.show()

# %%
# 2.Bar Plot---edge--color

import matplotlib.pyplot as plt

x = ["c","c++","JAVA","Python"]
y = [20,30,88,52]

plt.xlabel("Lanuages",fontsize=19)
plt.ylabel("Know")
plt.title("JUN-09-2024",fontsize=25)

colorss=["y","r","orange","b"]

plt.bar(x,y,color=colorss,edgecolor="black",linewidth=3,    linestyle=":", alpha=0.3)   # by default center
plt.show()

# %%
# 2.Bar Plot---multi--color

import matplotlib.pyplot as plt

x = ["c","c++","JAVA","Python"]
y = [20,30,88,52]

plt.xlabel("Lanuages",fontsize=19)
plt.ylabel("Know")


colorss=["y","r","orange","b"]

plt.bar(x,y,color=colorss,label="Programmimg Languages")   # by default center

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ["c","c++","JAVA","Python"]
y = [20,30,88,52]
z = [10,20,30,40]

plt.xlabel("Lanuages",fontsize=19)
plt.ylabel("Know")
plt.title("JUN-09-2024",fontsize=25)

col1=["y","r","y","r"]
col2=["orange","b","orange","b"]

# bar_width = 0.35

# x = np.arange(len(x))

plt.bar(x , y,  color=col1, label="2023")
plt.bar(x , z, color=col2, label="2024")
# plt.xticks(x, x)
plt.legend()
plt.show()

# %%
# 2 in 1

import matplotlib.pyplot as plt
import numpy as np

x = ["c","c++","JAVA","Python"]
y = [20,30,88,52]
z = [10,20,30,40]

plt.xlabel("Languages",fontsize=19)
plt.ylabel("Know")
plt.title("JUN-09-2024",fontsize=25)

col1=["y","r","y","r"]
col2=["orange","b","orange","b"]

bar_width = 0.35

x = np.arange(len(x))

plt.bar(x - bar_width/2, y, bar_width, color=col1, label="2023")
plt.bar(x + bar_width/2, z, bar_width, color=col2, label="2024")

plt.xticks(x, x)

plt.legend()
plt.show()
