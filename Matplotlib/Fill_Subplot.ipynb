# %%
# 1 basic syntax

import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [2,5,7,9]

plt.fill(x,y)
plt.show()

# %%
# 2 basic 

import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [1,2,3,4]

plt.plot(x,y,color="r")

plt.fill_bitween(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 10
#       6 y = [1,2,3,4]
#       8 plt.plot(x,y,color="r")
# ---> 10 plt.fill_bitween(x,y)
#      11 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'fill_bitween'

# %%
# 1.SUB_PLOT

import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [1,2,3,4]
plt.subplot(2,2,1)
plt.plot(x,y,color="r")

plt.subplot(2,2,2)
plt.pie([1],colors="r")

x1=[10,20,30,40]
plt.subplot(2,2,3)
plt.bar(x,y)
plt.show()
