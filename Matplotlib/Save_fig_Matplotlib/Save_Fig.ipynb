# %%
# 1.save graph in your system/memory

import matplotlib.pyplot as plt

x=[1,2,3,4,5,6,7,8,9]
y=[3,8,1,9,12,6,34,7,21]

plt.plot(x,y,color="r")
# imp save

plt.savefig("Line_Graph{10-06-2024}")

plt.show()

# %%
# 2.save graph in your system/memory

import matplotlib.pyplot as plt

x=[1,2,3,4,5,6,7,8,9]
y=[3,8,1,9,12,6,34,7,21]

plt.plot(x,y,color="r")

plt.savefig("2.Line_Graph10-06-2024.png",dpi=2000)

plt.show()

# %%
# 3

import matplotlib.pyplot as plt

x=[1,2,3,4,5,6,7,8,9]
y=[3,8,1,9,12,6,34,7,21]

plt.plot(x,y,color="r")

plt.savefig("3.Line_Graph10-06-2024.png",dpi=2000,facecolor="g")

plt.show()

# %%
# 4

import matplotlib.pyplot as plt

x=[1,2,3,4,5,6,7,8,9]
y=[3,8,1,9,12,6,34,7,21]

plt.plot(x,y,color="r")

plt.savefig("4.Line_Graph10-06-2024.png",dpi=2000,facecolor="orange",transparent=True)

plt.show()

# %%
print("Thanks")
print("Fig are sum time not show color that time deko photo file")
# Out:
# Thanks
# Fig are sum time not show color that time deko photo file
