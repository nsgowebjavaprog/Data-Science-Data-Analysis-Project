# %%
print("Hello Nagaraj how are you")
# Out:
# Hello Nagaraj how are you

# %%
# 1 Basic

import matplotlib.pyplot as plt
import numpy as np
import random        # ramdom number

x = np.random.randint(10,60,(20))
print(x)
# Out:
# [43 43 31 40 43 43 26 39 23 20 13 26 57 59 23 27 49 28 40 18]

# %%
# 2 implimentation

num = [43,43 ,31, 40, 43, 43, 26, 39, 23, 20, 13, 26, 57,55,54,59, 23, 27, 49 ,28 ,40,35,34 ,18]
plt.hist(num,color="r",edgecolor="y",linewidth=5)

plt.title("Knowledge {Histogram_Plot}")
plt.xlabel("Language")
plt.ylabel("Years")

plt.show()

# %%
# 3 Decreasing Order


num = [43,43 ,31, 40, 43, 43, 26, 39, 23, 20, 13, 26, 57,55,54,59, 23, 27, 49 ,28 ,40,35,34 ,18]
plt.hist(num,color="r",edgecolor="y",linewidth=5,cumulative=-1)

plt.title("Knowledge {Histogram_Plot}")
plt.xlabel("Language")
plt.ylabel("Years")

plt.show()

# %%
# 4  Increasing Order

# 3 Decreasing Order


num = [43,43 ,31, 40, 43, 43, 26, 39, 23, 20, 13, 26, 57,55,54,59, 23, 27, 49 ,28 ,40,35,34 ,18]
plt.hist(num,color="r",edgecolor="y",linewidth=5,cumulative=1)

plt.title("Knowledge {Histogram_Plot}")
plt.xlabel("Language")
plt.ylabel("Years")

plt.show()

# %%
# 5 Different Bar

num = [43,43 ,31, 40, 43, 43, 26, 39, 23, 20, 13, 26, 57,55,54,59, 23, 27, 49 ,28 ,40,35,34 ,18]
plt.hist(num,color="r",edgecolor="y",linewidth=5,histtype="stepfilled")

plt.title("Knowledge {Histogram_Plot}")
plt.xlabel("Language")
plt.ylabel("Years")

plt.show()

# %%
# 6  Different Bar

num = [43,43 ,31, 40, 43, 43, 26, 39, 23, 20, 13, 26, 57,55,54,59, 23, 27, 49 ,28 ,40,35,34 ,18]
plt.hist(num,color="r",edgecolor="y",linewidth=5,histtype="step")

plt.title("Knowledge {Histogram_Plot}")
plt.xlabel("Language")
plt.ylabel("Years")

plt.show()

# %%
# 7  Different Bar

num = [43,43 ,31, 40, 43, 43, 26, 39, 23, 20, 13, 26, 57,55,54,59, 23, 27, 49 ,28 ,40,35,34 ,18]
plt.hist(num,color="r",edgecolor="y",linewidth=5,histtype="barstacked")

plt.title("Knowledge {Histogram_Plot}")
plt.xlabel("Language")
plt.ylabel("Years")

plt.show()

# %%
# 8  Different Bar

num = [43,43 ,31, 40, 43, 43, 26, 39, 23, 20, 13, 26, 57,55,54,59, 23, 27, 49 ,28 ,40,35,34 ,18]
plt.hist(num,color="r",edgecolor="y",linewidth=5,orientation="horizontal")

plt.title("Knowledge {Histogram_Plot}")
plt.xlabel("Language")
plt.ylabel("Years")

plt.show()

# %%
# 9  Different Bar

num = [43,43 ,31, 40, 43, 43, 26, 39, 23, 20, 13, 26, 57,55,54,59, 23, 27, 49 ,28 ,40,35,34 ,18]
plt.hist(num,color="r",edgecolor="y",linewidth=5,rwidth=0.5)

plt.title("Knowledge {Histogram_Plot}")
plt.xlabel("Language")
plt.ylabel("Years")

plt.show()

# %%
# 10  Different Bar

num = [43,43 ,31, 40, 43, 43, 26, 39, 23, 20, 13, 26, 57,55,54,59, 23, 27, 49 ,28 ,40,35,34 ,18]
plt.hist(num,color="r",edgecolor="y",linewidth=5,log=True,rwidth=.2)

plt.title("Knowledge {Histogram_Plot}")
plt.xlabel("Language")
plt.ylabel("Years")

plt.show()
